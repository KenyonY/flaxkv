# %%
from flaxkv2 import FlaxKV
from flaxkv2.client.zmq_client import RemoteDBDict
import pandas as pd
import numpy as np
from sparrow import MeasureTime
db = FlaxKV("kunyuan", auto_nested=True, rebuild=True)
# Out:
# Warning: Some utils modules could not be imported: No module named 'Levenshtein'
# 2025-11-01 16:34:52 | INFO     | flaxkv2.core.raw_leveldb_dict:_init_db:222 - Opened raw LevelDB at /home/kunyuan/github/flaxkv/kunyuan
# 2025-11-01 16:34:52 | INFO     | flaxkv2.utils.ttl_cleanup:start:58 - TTLCleanup thread started

# %%
a = {'a': 1}

# %%
db.get('a')

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(1000000, 30))

# 统计占用内存大小
memory_size = df.memory_usage(deep=True).sum()
print(f"占用内存大小: {memory_size / 1024 / 1024} Mb")
# Out:
# 占用内存大小: 228.8819580078125 Mb

# %%
mt = MeasureTime()
mt.start()
db['df'] = df
mt.show_interval()
# Out:
# cost time: 2.695E+00
# 2.694901330396533

# %%
mt.start()
print(db['df'])
mt.show_interval()
# Out:
#               0         1         2         3         4         5         6   \
# 0       0.729505  0.798266  0.956055  0.175776  0.660875  0.838624  0.171986
# 1       0.769684  0.412663  0.215401  0.414221  0.156454  0.794946  0.292674
# 2       0.879439  0.517953  0.568891  0.282916  0.989716  0.048945  0.948679
# 3       0.828964  0.267315  0.956248  0.125531  0.365497  0.975992  0.181960
# 4       0.066474  0.183434  0.161709  0.040837  0.395672  0.765870  0.025288
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  0.214439  0.023428  0.106799  0.336863  0.307711  0.207308  0.516236
# 999996  0.708768  0.570909  0.165494  0.081512  0.771372  0.937127  0.522137
# 999997  0.444226  0.428484  0.080090  0.443538  0.310060  0.331495  0.877607
# 999998  0.394308  0.086527  0.148771  0.118264  0.210702  0.888265  0.374480
# 999999  0.058586  0.511429  0.626499  0.452946  0.534871  0.645285  0.944571
#
#               7         8         9   ...        20        21        22  \
# 0       0.768556  0.598943  0.588319  ...  0.214802  0.569183  0.185491
# 1       0.677892  0.280811  0.007628  ...  0.464900  0.581360  0.781033
# 2       0.223043  0.414213  0.626443  ...  0.228266  0.168868  0.197727
# 3       0.337546  0.869006  0.821770  ...  0.738443  0.768137  0.066283
# 4       0.412627  0.271032  0.570599  ...  0.892085  0.845910  0.005946
# ...          ...       ...       ...  ...       ...       ...       ...
# 999995  0.555966  0.656037  0.821015  ...  0.484450  0.299802  0.774048
# 999996  0.657203  0.755323  0.393726  ...  0.537050  0.095902  0.123191
# 999997  0.311237  0.457166  0.475316  ...  0.229538  0.774262  0.791266
# 999998  0.037243  0.935296  0.546139  ...  0.475961  0.069769  0.835276
# 999999  0.996661  0.054468  0.823613  ...  0.317189  0.775400  0.534075
#
#               23        24        25        26        27        28        29
# 0       0.614039  0.822261  0.978801  0.519230  0.248518  0.679679  0.029102
# 1       0.416356  0.618519  0.524905  0.707230  0.024879  0.200873  0.991816
# 2       0.473000  0.759188  0.737745  0.582481  0.412572  0.645870  0.065276
# 3       0.633664  0.205723  0.657610  0.690427  0.386467  0.985044  0.530737
# 4       0.226125  0.312572  0.144705  0.821862  0.905558  0.079390  0.814174
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  0.583760  0.219705  0.819721  0.453843  0.407290  0.352679  0.655202
# 999996  0.345865  0.677200  0.820645  0.894094  0.849308  0.788456  0.882457
# 999997  0.224375  0.113773  0.716492  0.659178  0.971749  0.967835  0.222247
# 999998  0.378728  0.610012  0.289699  0.894020  0.041244  0.221752  0.500882
# 999999  0.176800  0.458550  0.868053  0.107993  0.940896  0.491975  0.174901
#
# [1000000 rows x 30 columns]
# cost time: 2.361E+00
# 2.3605404403060675

# %%
db['df'] = 'df'

# %%
db['list'] = [1, 2, 3]

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'list': NestedDBList([1, 2, 3]), 'df': 'df'})

# %%
print(type(db['list']))
# Out:
# <class 'flaxkv2.core.nested_dict.NestedDBList'>

# %%
db['list']
# Out:
# NestedDBList([1, 2, 3])

# %%
li = db['list']

# %%
li[2] = 10

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'list': NestedDBList([1, 2, 10]), 'df': 'df'})

# %%
db['list'][2] = 10

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'df': 'df', 'list': [1, 2, 3]})

# %%
db['df'] = 'df'

# %%
db['dict'] = {"a": "a", 'b': 'b', 'd': {"c": "c"}}

# %%
d = db['dict']['d']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 d.set('a', b)
#
# AttributeError: 'NestedDBDict' object has no attribute 'set'

# %%
print(type(db['dict']))a
# Out:
# <class 'flaxkv2.core.nested_dict.NestedDBDict'>

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'dict': NestedDBDict({'a': 'a', 'b': 'b', 'd': NestedDBDict({'c': 'c'})}), 'df': 'df'})

# %%
db.set("a", 'a')

# %%
print(db)
# Out:
# {'a': 'a', 'df': 'df'}

# %%
db.set_ttl('a', 10)

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': 'a', 'df': 'df'})

# %%
print(db)
# Out:
# {'df': 'df'}

# %%
db.get('df')
# Out:
# 'df'

# %%
db = FlaxKV('remote_db', root_path_or_url="tcp://127.0.0.1:5555")#, rebuild=True)
# Out:
# 2025-10-29 13:37:28 | INFO     | flaxkv2.client.zmq_client:__init__:94 - RemoteDBDict connected to 127.0.0.1:5555, db=remote_db

# %%
db['a'] = {'a': {'a': 'asdf'}, 'b': {'b': "asdfoijpaidfj"}}

# %%
print(db)
# Out:
# {'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})}

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})})

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})})

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})})

# %%
db.set_ttl('a', 10)

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})})

# %%
dict(db)
# Out:
# {'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})}

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={})

# %%
db['a'] = 3

# %%
db.set_ttl('a', 2)

# %%
print(db)
# Out:
# {}

# %%
# db = FlaxKV("kunyuan", auto_nested=True, rebuild=True) 
db['a'] = {"ky": 10, "ll": 20}
db.set_ttl('a', 3)

# %%
print(db)
# Out:
# {'a': NestedDBDict({'ky': 10, 'll': 20}), 'a': NestedDBDict({'ky': 10, 'll': 20})}

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={})

# %%
db.set_ttl('a', 10)

# %%
db.get_ttl('a')
# Out:
# 0

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={})

# %%
print(db)
# Out:
# {}

# %%
print(db.get_ttl('10'))
# Out:
# None

# %%
print(db.get_ttl('a'))
# Out:
# None

# %%
print(db)
# Out:
# {'a': {'kunyuan': {'性别': '女', '学历': '初中'}, 'lingling': {'性别': '男', '学历': '小学'}}, 'b': 1}

# %%
db['a'] = {"kunyuan": {"性别": "女", "学历": "初中"}, "lingling": {"性别": "男", "学历": "小学"}}
db['b'] = 1

# %%
db.set_ttl('a', 50)

# %%
db.get_ttl('a')

# %%
db['a']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 db['a']
#
# NameError: name 'db' is not defined

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'b': 1})

# %%
print(db)
# Out:
# {'b': 1}

# %%
db.stat()
# Out:
# {'path': '/home/kunyuan/github/flaxkv/kunyuan',
#  'backend': 'raw_leveldb',
#  'leveldb_stats': '                               Compactions\nLevel  Files Size(MB) Time(sec) Read(MB) Write(MB)\n--------------------------------------------------\n',
#  'approximate_size_bytes': 0,
#  'approximate_size': '0 B',
#  'count': 2}

# %%
db = RemoteDBDict('test_db', host='127.0.0.1', port=5555, timeout=5000)
# Out:
# 2025-10-26 09:03:15 | INFO     | flaxkv2.client.zmq_client:__init__:95 - RemoteDBDict connected to 127.0.0.1:5555, db=test_db

# %%
db.ping()
# Out:
# True

# %%
db = FlaxKV(f'test_{num_items}', 'test_dbs', rebuild=True)

# %%
test_cases = [
         (5, "少于20个，应显示所有"),
         (20, "正好20个，应显示所有"),
         (25, "超过20个，应显示前20个"),
         (50, "50个，应显示前20个")
     ]

for num_items, description in test_cases:
    print(f"\n{'='*60}")
    print(f"测试: {num_items}个键值对 - {description}")
    print('='*60)
    
    db = FlaxKV(f'test_{num_items}', 'test_dbs', rebuild=True)
    
    # 添加数据
    for i in range(num_items):
        db[f'key_{i:03d}'] = i
    print(db)

# %%
d  = FlaxKV(db_name="example_db", default_ttl=60, )

# %%
d.close()
print(d)
# Out:
# <RawLevelDBDict 'example_db' (closed)>

# %%
d
# Out:
# RawLevelDBDict(name='example_db', closed=True)

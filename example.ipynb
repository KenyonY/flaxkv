# %%
from flaxkv2 import FlaxKV
from flaxkv2.client.zmq_client import RemoteDBDict
import pandas as pd
import numpy as np
from sparrow import MeasureTime
db = FlaxKV("kunyuan", auto_nested=True, rebuild=True)
# Out:
# Warning: Some utils modules could not be imported: No module named 'Levenshtein'
# 2025-11-01 16:00:38 | INFO     | flaxkv2.core.raw_leveldb_dict:_init_db:222 - Opened raw LevelDB at /home/kunyuan/github/flaxkv/kunyuan
# 2025-11-01 16:00:38 | INFO     | flaxkv2.utils.ttl_cleanup:start:58 - TTLCleanup thread started

# %%
a = {'a': 1}

# %%
db.get('a')

# %%
import pandas as pd
import numpy as np

df = pd.DataFrame(np.random.rand(1000000, 30))

# 统计占用内存大小
memory_size = df.memory_usage(deep=True).sum()
print(f"占用内存大小: {memory_size / 1024 / 1024} Mb")
# Out:
# 占用内存大小: 228.8819580078125 Mb

# %%
mt = MeasureTime()
mt.start()
db['df'] = df
mt.show_interval()
# Out:
# cost time: 3.688E+00
# 3.688172833994031

# %%
mt.start()
print(db['df'])
mt.show_interval()
# Out:
#               0         1         2         3         4         5         6   \
# 0       0.511809  0.685519  0.859546  0.926457  0.407171  0.816647  0.223441
# 1       0.625887  0.733974  0.850285  0.004716  0.967477  0.954243  0.610701
# 2       0.844073  0.650109  0.741322  0.772422  0.214587  0.624873  0.409069
# 3       0.502674  0.597419  0.607077  0.730456  0.044168  0.834875  0.851144
# 4       0.017879  0.788851  0.203483  0.943435  0.914013  0.656201  0.441396
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  0.962213  0.631360  0.024876  0.436489  0.680158  0.415560  0.555582
# 999996  0.671703  0.800069  0.607136  0.365600  0.791652  0.624844  0.992792
# 999997  0.546803  0.242215  0.564569  0.690112  0.986510  0.654174  0.740090
# 999998  0.955856  0.527860  0.993316  0.786380  0.416874  0.222669  0.751246
# 999999  0.618750  0.055925  0.003410  0.875929  0.534149  0.282009  0.111905
#
#               7         8         9   ...        20        21        22  \
# 0       0.173437  0.087265  0.819187  ...  0.666536  0.354285  0.791674
# 1       0.068283  0.149815  0.950751  ...  0.964531  0.170760  0.820544
# 2       0.195721  0.513009  0.373136  ...  0.237756  0.980499  0.466243
# 3       0.432123  0.713333  0.109856  ...  0.355055  0.092376  0.256942
# 4       0.529554  0.756367  0.332719  ...  0.643263  0.244637  0.441008
# ...          ...       ...       ...  ...       ...       ...       ...
# 999995  0.805930  0.759645  0.215866  ...  0.457853  0.050104  0.834750
# 999996  0.723841  0.127579  0.357353  ...  0.142172  0.630495  0.811376
# 999997  0.424087  0.531290  0.167881  ...  0.820113  0.228483  0.276392
# 999998  0.279303  0.066946  0.439846  ...  0.436852  0.408747  0.078780
# 999999  0.380612  0.068706  0.768569  ...  0.029525  0.245583  0.515375
#
#               23        24        25        26        27        28        29
# 0       0.778707  0.183775  0.398046  0.907958  0.311903  0.304044  0.964106
# 1       0.745969  0.480648  0.009824  0.003123  0.088169  0.128622  0.365342
# 2       0.525982  0.556921  0.622179  0.749026  0.298196  0.246170  0.461346
# 3       0.357461  0.556196  0.334195  0.188306  0.527700  0.649500  0.773173
# 4       0.541690  0.096593  0.373564  0.650314  0.180407  0.459288  0.047690
# ...          ...       ...       ...       ...       ...       ...       ...
# 999995  0.133344  0.802764  0.124967  0.941922  0.780772  0.137602  0.230354
# 999996  0.423298  0.657549  0.165851  0.838170  0.512824  0.801716  0.779560
# 999997  0.396704  0.816852  0.397432  0.981379  0.644825  0.611043  0.689891
# 999998  0.976755  0.773168  0.047069  0.908629  0.095897  0.534436  0.180487
# 999999  0.976770  0.220289  0.129729  0.822454  0.355977  0.891052  0.292375
#
# [1000000 rows x 30 columns]
# cost time: 2.846E+00
# 2.8456646744161844

# %%
d_f = db['df']

# %%
db['df'] = 'df'

# %%
db['list'] = [1, 2, 3]

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'df': 'df', 'list': [1, 2, 3]})

# %%
print(type(db['list']))
# Out:
# <class 'list'>

# %%
db['list']
# Out:
# [1, 2, 3]

# %%
db['list'][2] = 10

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'df': 'df', 'list': [1, 2, 3]})

# %%
db['df'] = 'df'

# %%
db['dict'] = {"a": "a", 'b': 'b', 'd': {"c": "c"}}

# %%
d = db['dict']['d']

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 d.set('a', b)
#
# AttributeError: 'NestedDBDict' object has no attribute 'set'

# %%
print(type(db['dict']))a
# Out:
# <class 'flaxkv2.core.nested_dict.NestedDBDict'>

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'dict': NestedDBDict({'a': 'a', 'b': 'b', 'd': NestedDBDict({'c': 'c'})}), 'df': 'df'})

# %%
db.set("a", 'a')

# %%
print(db)
# Out:
# {'a': 'a', 'df': 'df'}

# %%
db.set_ttl('a', 10)

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': 'a', 'df': 'df'})

# %%
print(db)
# Out:
# {'df': 'df'}

# %%
db.get('df')
# Out:
# 'df'

# %%
db = FlaxKV('remote_db', root_path_or_url="tcp://127.0.0.1:5555")#, rebuild=True)
# Out:
# 2025-10-29 13:37:28 | INFO     | flaxkv2.client.zmq_client:__init__:94 - RemoteDBDict connected to 127.0.0.1:5555, db=remote_db

# %%
db['a'] = {'a': {'a': 'asdf'}, 'b': {'b': "asdfoijpaidfj"}}

# %%
print(db)
# Out:
# {'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})}

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})})

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})})

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})})

# %%
db.set_ttl('a', 10)

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})})

# %%
dict(db)
# Out:
# {'a': NestedDBDict({'a': NestedDBDict({'a': 'asdf'}), 'b': NestedDBDict({'b': 'asdfoijpaidfj'})})}

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={})

# %%
db['a'] = 3

# %%
db.set_ttl('a', 2)

# %%
print(db)
# Out:
# {}

# %%
# db = FlaxKV("kunyuan", auto_nested=True, rebuild=True) 
db['a'] = {"ky": 10, "ll": 20}
db.set_ttl('a', 3)

# %%
print(db)
# Out:
# {'a': NestedDBDict({'ky': 10, 'll': 20}), 'a': NestedDBDict({'ky': 10, 'll': 20})}

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={})

# %%
db.set_ttl('a', 10)

# %%
db.get_ttl('a')
# Out:
# 0

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={})

# %%
print(db)
# Out:
# {}

# %%
print(db.get_ttl('10'))
# Out:
# None

# %%
print(db.get_ttl('a'))
# Out:
# None

# %%
print(db)
# Out:
# {'a': {'kunyuan': {'性别': '女', '学历': '初中'}, 'lingling': {'性别': '男', '学历': '小学'}}, 'b': 1}

# %%
db['a'] = {"kunyuan": {"性别": "女", "学历": "初中"}, "lingling": {"性别": "男", "学历": "小学"}}
db['b'] = 1

# %%
db.set_ttl('a', 50)

# %%
db.get_ttl('a')

# %%
db['a']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 db['a']
#
# NameError: name 'db' is not defined

# %%
db
# Out:
# RawLevelDBDict(name='kunyuan', path='/home/kunyuan/github/flaxkv/kunyuan', items={'b': 1})

# %%
print(db)
# Out:
# {'b': 1}

# %%
db.stat()
# Out:
# {'path': '/home/kunyuan/github/flaxkv/kunyuan',
#  'backend': 'raw_leveldb',
#  'leveldb_stats': '                               Compactions\nLevel  Files Size(MB) Time(sec) Read(MB) Write(MB)\n--------------------------------------------------\n',
#  'approximate_size_bytes': 0,
#  'approximate_size': '0 B',
#  'count': 2}

# %%
db = RemoteDBDict('test_db', host='127.0.0.1', port=5555, timeout=5000)
# Out:
# 2025-10-26 09:03:15 | INFO     | flaxkv2.client.zmq_client:__init__:95 - RemoteDBDict connected to 127.0.0.1:5555, db=test_db

# %%
db.ping()
# Out:
# True

# %%
db = FlaxKV(f'test_{num_items}', 'test_dbs', rebuild=True)

# %%
test_cases = [
         (5, "少于20个，应显示所有"),
         (20, "正好20个，应显示所有"),
         (25, "超过20个，应显示前20个"),
         (50, "50个，应显示前20个")
     ]

for num_items, description in test_cases:
    print(f"\n{'='*60}")
    print(f"测试: {num_items}个键值对 - {description}")
    print('='*60)
    
    db = FlaxKV(f'test_{num_items}', 'test_dbs', rebuild=True)
    
    # 添加数据
    for i in range(num_items):
        db[f'key_{i:03d}'] = i
    print(db)

# %%
d  = FlaxKV(db_name="example_db", default_ttl=60, )

# %%
d.close()
print(d)
# Out:
# <RawLevelDBDict 'example_db' (closed)>

# %%
d
# Out:
# RawLevelDBDict(name='example_db', closed=True)
